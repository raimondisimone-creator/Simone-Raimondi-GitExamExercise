# %%
'''
Cella 1: import del modulo creato.
'''

import modules as m

print("Cella 1: Caricamento del modulo completato.")
# Out:
# Cella 1: Caricamento del modulo completato.

# %%
'''
Cella 2: esecuzione del primo metodo presente nel modulo e assegnazione di una variabile.
'''

m.HelloWorld()

x = int(5)
print("Cella 2: Esecuzione del primo metodo completata e variabile x assegnata.")
# Out:
# Hello World!
# Cella 2: Esecuzione del primo metodo completata e variabile x assegnata.

# %%
'''
Cella 3: esecuzione di tutti gli altri metodi presenti nel modulo con risultati a schermo.
'''

res = m.CalculateFactorial(x)
print(f"Il fattoriale di {x} è {res}.")

print("Il grafico di una funzione seno generica è mostrato di seguito:")
m.PlotSineWave()

print("Cella 3: Esecuzione di tutti i metodi completata.")
# Out:
# Il fattoriale di 5 è 120.
# Il grafico di una funzione seno generica è mostrato di seguito:
# Cella 3: Esecuzione di tutti i metodi completata.
